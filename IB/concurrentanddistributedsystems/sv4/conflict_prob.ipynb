# %%
from decimal import Decimal, getcontext
from tqdm import tqdm
import math

# %%
n = 1000000
b = 64
k = math.comb(n, 2)
getcontext().prec = 10000
(Decimal(1000 * 2 ** b - 1) / Decimal(1000 * 2 ** 64)) ** Decimal(k)
# Out:
# Decimal('0....')
